# %% [markdown]
# # Test de Carga de Datos y Exploración Inicial
#
# Este notebook tiene como objetivo verificar que la estructura de carpetas y el módulo de carga de datos (`src.data.loader`) funcionan correctamente.

# %%
import sys
import os
import pandas as pd

# Añadimos la raíz del proyecto al path para poder importar desde 'src'
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from src.data.loader import load_raw_data

print("Directorio actual:", os.getcwd())
print("Path de módulos:", module_path)
# Out:
# Directorio actual: c:\Users\sofia\IA\IA4\ciber\p1\P1_Ap-IA\notebooks
# Path de módulos: c:\Users\sofia\IA\IA4\ciber\p1\P1_Ap-IA

# %% [markdown]
# ## 1. Cargar datos
# Utilizamos la función modular definida en `src/data/loader.py`.

# %%
# La ruta relativa es desde la raíz del proyecto
df = load_raw_data("../data/raw/db.csv")

print(f"Dataset cargado con {df.shape[0]} filas y {df.shape[1]} columnas.")
df.head()
# Out:
# Dataset cargado con 2385 filas y 5 columnas.
#                     Description       Date  Amount       Area      Type
# 0  Streaming plataforma digital 2026-02-28   10.00    Leisure  Expenses
# 1        Nómina mensual trabajo 2026-02-27  629.58     Salary    Income
# 2         Alquiler bici turismo 2026-02-25   51.00  Vacations  Expenses
# 3              Salida bar copas 2026-02-22    2.80    Leisure  Expenses
# 4    Compra diaria alimentación 2026-02-21   24.80       Food  Expenses

# %% [markdown]
# ## 2. Inspección rápida
# Revisamos tipos de datos y valores nulos.

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2385 entries, 0 to 2384
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Description  2385 non-null   str
#  1   Date         2385 non-null   datetime64[us]
#  2   Amount       2385 non-null   float64
#  3   Area         2385 non-null   str
#  4   Type         2385 non-null   str
# dtypes: datetime64[us](1), float64(1), str(3)
# memory usage: 93.3 KB

# %%
# Resumen estadístico de importes
df.describe()
# Out:
#                              Date       Amount
# count                        2385  2385.000000
# mean   2018-11-18 10:17:39.622641    40.678138
# min           2010-02-01 00:00:00     0.010000
# 25%           2015-01-05 00:00:00     9.400000
# 50%           2019-05-08 00:00:00    20.050000
# 75%           2022-09-25 00:00:00    43.410000
# max           2026-02-28 00:00:00  1842.170000
# std                           NaN    92.986887
